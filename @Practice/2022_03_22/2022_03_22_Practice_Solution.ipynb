# %% [markdown]
# # Самостоятельная работа №3
#
# Максимум: 12 баллов. Максимальная оценка: 10 баллов.
#
# Запустите код ниже. Это ваш референс.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
bikes = pd.read_pickle('https://github.com/rogovich/Data/blob/master/data/BikesDataImputed.pkl?raw=true')

fig, ax = plt.subplots(2,2, figsize=(20,10))

ax[0][0].plot(bikes.groupby(['Seasons', 'Date'])['Temperature'].mean().loc['Autumn'], c='#ff8c69')
ax[0][1].plot(bikes.groupby(['Seasons', 'Date'])['Temperature'].mean().loc['Winter'], c='#ff8c69')
ax[1][0].plot(bikes.groupby(['Seasons', 'Date'])['Temperature'].mean().loc['Spring'], c='#ff8c69')
ax[1][1].plot(bikes.groupby(['Seasons', 'Date'])['Temperature'].mean().loc['Summer'], c='#ff8c69')

for axis,season in zip(ax.ravel(), ['Autumn', 'Winter', 'Spring', 'Summer']):
    axis.set_xlabel('Date', fontsize=14)
    axis.set_ylabel('Temperature', fontsize=14)
    axis.spines['right'].set_visible(False)
    axis.spines['top'].set_visible(False)
    axis.spines['left'].set_linewidth(0.2)
    axis.spines['bottom'].set_linewidth(0.2)
    axis.xaxis.set_tick_params(width=0.2)
    axis.yaxis.set_tick_params(width=0.2)
    axis.set_ylim(-20, 39)
    axis.axhline(12.9, c='grey', lw=0.25)
    axis.legend([season, 'Annual average'], frameon=False, loc=2)
        
fig.suptitle('Temerature daily means by season', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Temerature daily means by season')

# %% [markdown]
# Загрузите датасет

# %%
import pandas as pd
forest = pd.read_csv('https://github.com/rogovich/Data/raw/master/data/populations.txt',
                     sep='\t')
forest
# Out:
#     year     hare     lynx  carrot
# 0   1900  30000.0   4000.0   48300
# 1   1901  47200.0   6100.0   48200
# 2   1902  70200.0   9800.0   41500
# 3   1903  77400.0  35200.0   38200
# 4   1904  36300.0  59400.0   40600
# 5   1905  20600.0  41700.0   39800
# 6   1906  18100.0  19000.0   38600
# 7   1907  21400.0  13000.0   42300
# 8   1908  22000.0   8300.0   44500
# 9   1909  25400.0   9100.0   42100
# 10  1910  27100.0   7400.0   46000
# 11  1911  40300.0   8000.0   46800
# 12  1912  57000.0  12300.0   43800
# 13  1913  76600.0  19500.0   40900
# 14  1914  52300.0  45700.0   39400
# 15  1915  19500.0  51100.0   39000
# 16  1916  11200.0  29700.0   36700
# 17  1917   7600.0  15800.0   41800
# 18  1918  14600.0   9700.0   43300
# 19  1919  16200.0  10100.0   41300
# 20  1920  24700.0   8600.0   47300

# %% [markdown]
# ## Задание
#
# Каждый пункт — 1 балл.
#
# 1. Нарисуйте в первом графике изменения в популяции зайцев (hare). x — год, y — количество зайцев.
# 2. Нарисуйте во втором графике изменения в популяции рысей (lynx).
# 3. В третьем - морковки (carrot).
# 4. В четвертом - все три графика вместе.
# 5. Каждый график должен быть разного цвета, выберите цвета, которые вам нравятся по шкале [hex-color](https://www.google.com/search?q=hex+color&oq=hex+color&aqs=chrome.0.0i512l10.2965j0j7&sourceid=chrome&ie=UTF-8).
# 6. Используйте линии разного стиля для каждого графика — 'solid', 'dotted', 'dashed' **Четвертый график: каждый график должен быть такого же цвета и с тем же стилем линии, как и в своей ячейке.**
# 8. Подпишите шкалу `y` для каждого графика (зайцы, рыси или морковки)
# 9. В цикле подпишите шкалу `x` у каждого графика (время)
# 10. В цикле уберите верхнюю и правую границу у каждого графика.
# 11. В цикле для всех графиков выставьте лимиты шкалы `y` (0, 80000)
# 12. На четвертом графике добавьте легенду с лейблами
# 13. Добавьте суперзаголовок всего графика

# %%
# ваш код здесь

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2,2, figsize=(20,10))
# 1, 5, 6
ax[0][0].plot(forest['year'], forest['hare'], c='#34eb8f', ls='solid')
# 2, 5, 6
ax[0][1].plot(forest['year'], forest['lynx'], c='#b426d4', ls='dotted')
# 3, 5, 6
ax[1][0].plot(forest['year'], forest['carrot'], c='#d4cb26', ls='dashed')
# 4, 5, 6
ax[1][1].plot(forest['year'], forest['hare'], c='#34eb8f', ls='solid')
ax[1][1].plot(forest['year'], forest['lynx'], c='#b426d4', ls='dotted')
ax[1][1].plot(forest['year'], forest['carrot'], c='#d4cb26', ls='dashed')
# 10
ax[1][1].legend(['Зайцы', 'Рыси', 'Морковки'], frameon=False) #frameon — необязательно

# 7 (необязательной в цикле)
# 8, 9, 10
for axis,title in zip(ax.ravel(), ['Количество зайцев', 'Количество рысей', "Количество морковок", "Общее количество"]):
    axis.set_ylabel(title, fontsize=14) # fontsize = необязательно
    axis.set_xlabel('Годы', fontsize=14) # fontsize = необязательно
    axis.set_ylim(0, 80000)
    axis.spines['right'].set_visible(False)
    axis.spines['top'].set_visible(False)
        
# 11
fig.suptitle('Динамика популяций зайцев, рысей и морковок с 1900 по 1920 годы', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Динамика популяций зайцев, рысей и морковок с 1900 по 1920 годы')
