# %% [markdown]
# *Авторы: Татьяна Рогович*
#
# # Python Refresher | Задачи 2 | Решение
#
# *Примечание: под программой в заданиях подразумевается просто блок работающего кода, который выполняет нужную задачу. Для удобства можно считать, что одна ячейка с кодом – это одна программа.*

# %% [markdown]
# ### Задание 1 (логическое)
#
# Даны три целых числа. Определите, сколько среди них совпадающих. Программа должна вывести одно из чисел: 3 (если все совпадают), 2 (если два совпадает) или 0 (если все числа различны).
#
# **Формат ввода**
# Вводятся три целых числа
#
# **Формат вывода**
# Целое число

# %%
# ваше решение здесь
# место для решения
a = int(input())
b = int(input())
c = int(input())

if a == b == c:
    print(3)
elif a == b or a == c or b == c:
    print(2)
else:
    print(0)
# Out:
# 2

# %% [markdown]
# ### Задание 2 (зацикленное)
#
# Дано целое число, не меньшее 2. Выведите его наименьший натуральный делитель, отличный от 1.
#
# **Формат ввода**
# Вводится целое положительное число
#
# **Формат вывода**
# Выведите ответ на задачу
#
# **Пример**
#
# **Ввод**
# 15
#
# **Вывод**
# 3

# %%
# место для решения

x = int(input())
number = 2

while number <= x:
    if x % number == 0:
        print(number)
        break
    else:
        number += 1
# Out:
# 11

# %% [markdown]
# ### Задание 3 (поисковое)
# Последовательность состоит из натуральных чисел и завершается числом 0. Определите, сколько элементов этой последовательности больше предыдущего элемента.
#
# **Формат ввода:**
# Вводится последовательность целых чисел, оканчивающаяся числом 0 (само число 0 в последовательность не входит, а служит как признак ее окончания).
#
# **Формат вывода:**
# Выведите ответ на задачу.
#
# *Подсказка*
# Обработайте первое число до цикла и сохраните его в отдельную переменную (предыдущее число). Проверьте, что ваша программа правильно работает для пустой последовательности.
#
# Также для тренировки попробуйте решить задачу со списками и без
#
# **Пример ввода:**
#
# 1
# 7
# 9
# 0
#
# **Пример вывода:**
# 2

# %%
# ваше решение здесь

# решение здесь
count = 0
n_previous = int(input())
while True:
    n = int(input())
    if n == 0:
        break
    else:
        if n > n_previous:
            count += 1
            
print(count)
# Out:
# 2

# %% [markdown]
# ### Задание 4 (олимпиадное)
#
# В олимпиаде по программированию задачи имеют три уровная сложности: "базовый" (б), "повышенный" (п) и "сложный" (c). Максимальное количество баллов, которое можно получить за каждую задачу составляет  **10,** однако, задачи имеют веса в зависимости от уровня сложности. Задачи базового уровня имеют вес **1**, повышенного - **1,5**, а сложного - **3** (количество баллов, полученных участником, умножается на "вес" задачи). Необходимо определить суммарное количество набранных баллов.
#
# **Формат ввода:**
#
# *   Множество пар вида “уровень задачи(буква) - набранное количество баллов (действительное число)”. Количество таких пар может быть разным.
# Каждая пара вводится с новой строки, ввод заканчивается нулем.
#
# **Формат вывода:**
#
# *   Действительное число (сумма баллов).
#
# **Пример:**
#
# **Ввод:**
#
# б 2
# п 2
# с 4
# с 7
# б 1
# 0
#
# **Вывод:**
#
# 39.0

# %%
# ваше решение здесь
# решение здесь
total = 0
while True:
    n = input().split()
    if n[0] == '0':
        break
    else:
        if n[0] == 'б':
            total += int(n[1])
        elif n[0] == 'п':
            total += int(n[1]) * 1.5
        else:
            total += int(n[1]) * 3
            
print(total)
# Out:
# 39.0

# %% [markdown]
# ### Задание 5 (схематичное)
#
# Реализуйте код для обеих блок-схем в условии задачи
#
# ![](https://github.com/rogovich/2020_DPO_PythonProg/blob/master/2_Containers_Conditions/img/1.png?raw=true)

# %%
# решение для схемы 1 здесь
# решение здесь
mark = int(input("Введите оценку: "))

if mark < 10:
    print("Это нормально")
elif mark == 10:
    print("Отлично")
if mark < 6:
    print("Плохо")
# Out:
# Это нормально

# %% [markdown]
# ![](https://github.com/rogovich/2020_DPO_PythonProg/blob/master/2_Containers_Conditions/img/2.png?raw=true)

# %%
# решение для схемы 2 здесь
# решение здесь

if mark < 10:
    print("Это нормально")
elif mark == 10:
    print("Отлично")
elif mark < 6:
    print("Плохо")
# Out:
# Это нормально

# %% [markdown]
# ### Задание 8 (на срезы)
#
# Используя список `girls`, выведите на экран с помощью срезов следующие списки:
#
#     ["Виолетта", "Кассандра", "Вирджиния", "Амелия"]
#     ["Вирджиния", "Амелия", "Розамунда", "Янина", "Беатриса"]
#     ["Иветта", "Виолетта", "Вирджиния", "Амелия"]
#     ["Кассандра", "Амелия", "Розамунда"]

# %%
girls = ["Иветта", "Виолетта", "Кассандра", "Вирджиния", 
         "Амелия", "Розамунда", "Янина", "Беатриса"]

# решение здесь
print(girls[1:5])
print(girls[3:])
print(girls[:2] + girls[3:5])
print([girls[2]] + girls[4:6])
# Out:
# ['Виолетта', 'Кассандра', 'Вирджиния', 'Амелия']
# ['Вирджиния', 'Амелия', 'Розамунда', 'Янина', 'Беатриса']
# ['Иветта', 'Виолетта', 'Вирджиния', 'Амелия']
# ['Кассандра', 'Амелия', 'Розамунда']

# %% [markdown]
# ### Задание 10 (строковое)
#
# Дана строка. Найдите в этой строке второе вхождение буквы f и выведите индекс этого вхождения. Если буква f в данной строке встречается только один раз, выведите число -1, а если не встречается ни разу, выведите число -2. При решении этой задачи нельзя использовать метод count.
#
# **Формат ввода**
#
# Вводится строка.
#
# **Формат вывода**
#
# Выведите ответ на задачу.
#
# **Примеры**
#
# **Тест 1**
# Входные данные:
# comfort
#
# Вывод программы:
# -1
#
# **Тест 2**
# Входные данные:
# coffee
#
# Вывод программы:
# 3
#
# **Тест 3**
# Входные данные:
# qwerty
#
# Вывод программы:
# -2

# %%
# ваше решение здесь
# ваше решение
x = input()

if x.find('f') == -1:
    print(-2)
else:
    first = x.find('f')
    if x[first+1:].find('f') == -1:
        print(-1)
    else:
        print(x[first+1:].find('f') + first + 1)
# Out:
# 3

# %% [markdown]
# ### Задание 11 (самое длинное)
#
# Дана строка, состоящая из слов, записанных через пробел. Найдите и выведите длину самого длинного слова. Слово - непрерывная последовательность непробельных символов (^%#^4fhjkdslgds - слово).
#
# Максимум списка можно найти с помощью функции max().
#
# **Формат ввода**
#
# Вводится строка из слов, записанных через пробел.
#
# **Формат вывода**
#
# Выведите ответ на задачу.
#
# **Примеры**
# **Тест 1**
# Входные данные:
# Python C++ Perl Ruby Brainfuck
#
# Вывод программы:
# 9
#
# **Тест 2**
# Входные данные:
# Hello Yes
#
# Вывод программы:
# 5
#
# **Тест 3**
# Входные данные:
# A
#
# Вывод программы:
# 1

# %%
# решение здесь
# ваше решение здесь
x = input().split()
print(max(map(len, x)))
# Out:
# 9

# %% [markdown]
# ### Задание 12 (факультативное (на самом деле нет)
# Группа из 3 студентов пишет заявки на желаемые факультативы из списка: английский, немецкий, право, математика, сольфеджио. Факультатив откроют, если на него запишутся все студенты. Каждый студент может выбрать минимум один и максимум три факультатива. Нужно посчитать количество факультативов, которые откроются.
#
# *Пример*
#
# **Ввод:**
#
# английский сольфеджио право
# математика сольфеджио
# немецкий право
#
# **Вывод:**
#
# 0
#
# **Ввод:**
#
# математика немецкий право
# математика немецкий
# немецкий право математика
#
# **Вывод:**
# 2

# %%
# считываем значения для каждого студента. input() принимает на ввод строку вида 'немецкий право математика'
# split() разбивает ее по пробелам и делает из нее список вида ['немецкий', 'право', 'математика'] (каждое слово, отделенное пробелом, стало объектом в нем)
# set() из этого списка делает множество (уникальные предметы, которые выбрал студент)
stud1 = set(input().split())
stud2 = set(input().split())
stud3 = set(input().split())
print(len(stud1 & stud2 & stud3)) # находим пересечение трех множеств (факультативы, которые общие для всех трех студентов) и смотрим, сколько объектов в этом множестве (len())
# Out:
# 2

# %% [markdown]
# Давайте модифицируем эту задачу, и представим, что только два студента выбирают факультативы, откроются факультативы, которые выбрал, хотя бы один студент. Но затем выясняется, что один из факультативов из списка отменили. Выводить будет через запятую те факультативы, которые откроются.
#
# *Пример*
# **Ввод:**
#
# математика немецкий право
# математика английский
# право
#
# **Вывод:**
# математика, немецкий, английский

# %%
# решение 1
stud1 = set(input().split())
stud2 = set(input().split())
cancelled = input()

opened = (stud1 | stud2)
opened.discard(cancelled)
print(*opened, sep=', ')
# Out:
# математика, английский, немецкий

# %% [markdown]
# ### Задание 13 (словарное)
#
# Вам дан словарь, содержащий в себе списки словарей. Напишите код, который выведет на экран 'разработчик' из списка ключа Windows в в первом словаре из списка 2.

# %%
dict_of_lists = {'Список1': [{'Python': 'язык программирования'}, {'R':'язык программирования', 'LaTEX' : 'язык верстки' }], 
                 'Список2' : [{'Windows' : ['операционная система', 'разработчик'], 'UNIX' : 'операционная система'},
                              {'IBM': ['компания-производитель', 'разработчик'], 'IPv6' : 'интернет-протокол' }]}

# ваше решение здесь
dict_of_lists['Список2'][0]['Windows'][1]
# Out:
# 'разработчик'

# %% [markdown]
# ### Задание 14 (на самом деле очень простое)
#
# Дан список чисел, который может содержать до 100000 чисел. Определите, сколько в нем встречается различных чисел.
#
# #### Пример 1
#
# ##### Ввод
#
# 1 2 3 2 1
#
# ##### Вывод
#
# 3
#
# #### Пример 2
# ##### Ввод
#
# 1 2 3 4 5 1 2 1 2 7 3
#
# ##### Вывод
# 6

# %%
# решение здесь

lst = set(map(int, input().split()))
print(len(lst))
# Out:
# 6

# %% [markdown]
# ### Задание 15 (аббревиатурное)
#
# Дана строка, состоящая из слов. С помощью цикла сделайте из нее аббревиатуру.
#
# **Вход:** "Комитет Государственной Безопасности"
#
# **Выход:** "КГБ"

# %%
# решение здесь
x = input()
short = ''
for word in x.split():
    short += word[0]
    
print(short)
# Out:
# КГБ

# %% [markdown]
# ### Задание 16 (почти боевое)
# Давайте теперь поработаем с настоящим файлом и действительно посчитаем в нем слова. Мы загрузим метаданные почтового сервера университета Мичигана. И попробуем найти, с какого адреса ушло больше всего писем. Автор письма находится в строке, которая начинается с 'From '.
#
# Бонус: выведите все адреса и количество отправленных писем, отсортированных по возрастанию количества писем
#
# Используйте файл mbox.txt (лежит в папке семинара в репозитории)
#
# **Входной файл: mbox.txt**

# %%
# решение здесь
fh = open('mbox.txt')

emails = []
for line in fh:
    if line.startswith('From '):
        emails.append(line.split()[1])
        
emails_dict = {}
for email in set(emails):
    emails_dict[email] = emails.count(email)
    
max_emails = max(emails_dict.values())

for email in emails_dict:
    if emails_dict[email] == max_emails:
        print(email)
# Out:
# zqian@umich.edu

# %% [markdown]
# ### Задание 17 (не менее боевое)
# Работаем с тем же файлом. У каждого письма есть метрика X-DSPAM-Confidence - уверенность фильтра в том, что это письмо не спам. Нужно посчитать среднее значение этой метрики для всей переписки.

# %%
# решение здесь
fh = open('mbox.txt')

total = 0
count = 0
for line in fh:
    if line.startswith('X-DSPAM-Confidence:'):
        total += float(line.split()[-1])
        count += 1
        
print(total/count)
# Out:
# 0.8941280467445736

# %% [markdown]
# ### Задача 18 (объединительная)
#
# Напишите программу, которая объединяет значения из двух списков.
#
# Ввод:
#
#     shops = [{'товар': 'яблоки', 'количество': 400}, {'товар': 'конфеты', 'количество': 300}, {'товар': 'яблоки', 'количество': 750}]
#
#
# Вывод:
#
#     {'яблоки': 1150, 'конфеты': 300}

# %%
shops = [{'товар': 'яблоки', 'количество': 400}, 
         {'товар': 'конфеты', 'количество': 300}, 
         {'товар': 'яблоки', 'количество': 750}]

# %%
# ваше решение здесь
total = {}
for shop in shops:
    if shop['товар'] not in total:
        total[shop['товар']] = shop['количество']
    else:
        total[shop['товар']] += shop['количество']
        
total
# Out:
# {'яблоки': 1150, 'конфеты': 300}

# %% [markdown]
# ### Задача 19 (не забываем про range!)
#
# Найти все числа от 100 до 300 включительно, все цифры которых четные.
#
# Программа должна выдавать результат в виде разделенной запятыми строки

# %%
# ваше решение здесь
print(*range(100,301,2), sep=',')
# Out:
# 100,102,104,106,108,110,112,114,116,118,120,122,124,126,128,130,132,134,136,138,140,142,144,146,148,150,152,154,156,158,160,162,164,166,168,170,172,174,176,178,180,182,184,186,188,190,192,194,196,198,200,202,204,206,208,210,212,214,216,218,220,222,224,226,228,230,232,234,236,238,240,242,244,246,248,250,252,254,256,258,260,262,264,266,268,270,272,274,276,278,280,282,284,286,288,290,292,294,296,298,300

# %% [markdown]
# ### Задача 20 (сортировочная)
#
# Найти количество цифр и количество букв в строке
#
# Вход: "абвгд 234"
#
#
# Выход:
#
#     Цифры: 3
#     Буквы: 5

# %%
# ваше решение здесь
x = "абвгд 234"
letters = 0
digits = 0
for symbol in x:
    if symbol.isalpha():
        letters += 1
    if symbol.isdigit():
        digits += 1
        
print(f'Цифры: {digits}')
print(f'Буквы: {letters}')
# Out:
# Цифры: 3
# Буквы: 5

# %% [markdown]
# ### Задание 21 (уже вам знакомое, но тем не менее)
#
# Вася составил таблицу с ценами на продукты в разных магазинах. В первой строке таблицы (кроме первой ячейки) записаны названия продуктов. Во всех строках, начиная со второй, записана информация о ценах в магазине. В первой ячейке написано название магазина, а в ячейках, начиная со второй - цена на товар, название которого записано в первой строке соответствующего столбца.
#
# Таблица задана как csv-файл, разделителем ячеек выступает точка с запятой, а строковые константы не окружаются кавычками. При открытии файла задайте кодировку utf8.
#
# Вася очень хочет поесть, но денег у него мало. Поэтому помогите ему определить самый дешевый продукт и в каком магазине он продается. Название продукта следует записать в первой строке, а название магазина - во второй. Если несколько товаров стоят одинаково, то выведите то название, которое раньше в алфавитном порядке. Если этот товар продается в нескольких магазинах по одной минимальной цене, то выведите минимальное в алфавитном порядке название магазина.
#
# Задачу нужно решить без использования специальных библиотек для работы с табличными данными.
#
# **Входной файл: problem21.csv**

# %%
# решение здесь

with open('problem21.csv', encoding='utf8') as fh:
    rows = []
    for line in fh.readlines():
        rows.append(line.strip().split(';'))

#for row in rows:
#    print(row)

min_prices = {}
for row in rows[1:]:
    min_store = min(map(int, row[1:]))
    min_prices[row[0]] = (min_store, rows[0][row.index(str(min_store))])
                          
min_price = min(min_prices.values())

answer = []
for key, value in min_prices.items():
    if value[0] == min_price[0]:
        answer.append([value[1], key])
        
print(*sorted(answer)[0], sep='\n')
# Out:
# Листья собачьей петрушки
# Магнит
